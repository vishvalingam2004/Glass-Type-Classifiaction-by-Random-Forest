# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('glass.csv')

# %%
display(df)
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
df.columns
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type'], dtype='object')

# %%
df.shape
# Out:
# (214, 10)

# %%
cor=df.corr()
cor.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_653f8_row0_col0, #T_653f8_row1_col1, #T_653f8_row2_col2, #T_653f8_row3_col3, #T_653f8_row4_col4, #T_653f8_row5_col5, #T_653f8_row6_col6, #T_653f8_row7_col7, #T_653f8_row8_col8, #T_653f8_row9_col9 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_653f8_row0_col1 {
#   background-color: #f5f4f9;
#   color: #000000;
# }
# #T_653f8_row0_col2 {
#   background-color: #c0c1de;
#   color: #000000;
# }
# #T_653f8_row0_col3 {
#   background-color: #f7f6fa;
#   color: #000000;
# }
# #T_653f8_row0_col4, #T_653f8_row1_col8, #T_653f8_row2_col1, #T_653f8_row2_col3, #T_653f8_row2_col6, #T_653f8_row2_col7, #T_653f8_row2_col9, #T_653f8_row4_col0, #T_653f8_row5_col1, #T_653f8_row6_col1, #T_653f8_row6_col5, #T_653f8_row9_col2 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_653f8_row0_col5 {
#   background-color: #faf9fc;
#   color: #000000;
# }
# #T_653f8_row0_col6 {
#   background-color: #552890;
#   color: #f1f1f1;
# }
# #T_653f8_row0_col7, #T_653f8_row4_col2 {
#   background-color: #c7c8e1;
#   color: #000000;
# }
# #T_653f8_row0_col8 {
#   background-color: #cccce4;
#   color: #000000;
# }
# #T_653f8_row0_col9 {
#   background-color: #c6c7e1;
#   color: #000000;
# }
# #T_653f8_row1_col0, #T_653f8_row7_col6 {
#   background-color: #dedded;
#   color: #000000;
# }
# #T_653f8_row1_col2, #T_653f8_row2_col0 {
#   background-color: #d5d5e9;
#   color: #000000;
# }
# #T_653f8_row1_col3, #T_653f8_row5_col2 {
#   background-color: #aeadd3;
#   color: #000000;
# }
# #T_653f8_row1_col4, #T_653f8_row9_col6 {
#   background-color: #cdcde4;
#   color: #000000;
# }
# #T_653f8_row1_col5, #T_653f8_row9_col8 {
#   background-color: #f8f7fa;
#   color: #000000;
# }
# #T_653f8_row1_col6 {
#   background-color: #f0eef6;
#   color: #000000;
# }
# #T_653f8_row1_col7 {
#   background-color: #928fc3;
#   color: #f1f1f1;
# }
# #T_653f8_row1_col9, #T_653f8_row9_col7 {
#   background-color: #705ca9;
#   color: #f1f1f1;
# }
# #T_653f8_row2_col4, #T_653f8_row2_col5, #T_653f8_row9_col0 {
#   background-color: #dbdbec;
#   color: #000000;
# }
# #T_653f8_row2_col8, #T_653f8_row4_col7 {
#   background-color: #d8d8ea;
#   color: #000000;
# }
# #T_653f8_row3_col0, #T_653f8_row5_col6 {
#   background-color: #f3f1f7;
#   color: #000000;
# }
# #T_653f8_row3_col1 {
#   background-color: #c5c6e1;
#   color: #000000;
# }
# #T_653f8_row3_col2, #T_653f8_row6_col3 {
#   background-color: #ebe9f3;
#   color: #000000;
# }
# #T_653f8_row3_col4, #T_653f8_row7_col0 {
#   background-color: #c2c3df;
#   color: #000000;
# }
# #T_653f8_row3_col5 {
#   background-color: #a09dca;
#   color: #f1f1f1;
# }
# #T_653f8_row3_col6 {
#   background-color: #efedf5;
#   color: #000000;
# }
# #T_653f8_row3_col7, #T_653f8_row7_col3 {
#   background-color: #7b74b5;
#   color: #f1f1f1;
# }
# #T_653f8_row3_col8 {
#   background-color: #eeecf4;
#   color: #000000;
# }
# #T_653f8_row3_col9 {
#   background-color: #66499f;
#   color: #f1f1f1;
# }
# #T_653f8_row4_col1, #T_653f8_row4_col6, #T_653f8_row5_col0 {
#   background-color: #e9e8f2;
#   color: #000000;
# }
# #T_653f8_row4_col3 {
#   background-color: #c9c9e2;
#   color: #000000;
# }
# #T_653f8_row4_col5 {
#   background-color: #f2f0f7;
#   color: #000000;
# }
# #T_653f8_row4_col8 {
#   background-color: #f0eef5;
#   color: #000000;
# }
# #T_653f8_row4_col9 {
#   background-color: #9b97c6;
#   color: #f1f1f1;
# }
# #T_653f8_row5_col3 {
#   background-color: #9390c3;
#   color: #f1f1f1;
# }
# #T_653f8_row5_col4 {
#   background-color: #dedeed;
#   color: #000000;
# }
# #T_653f8_row5_col7 {
#   background-color: #cecee5;
#   color: #000000;
# }
# #T_653f8_row5_col8 {
#   background-color: #e4e3f0;
#   color: #000000;
# }
# #T_653f8_row5_col9 {
#   background-color: #b1b1d5;
#   color: #000000;
# }
# #T_653f8_row6_col0 {
#   background-color: #53268f;
#   color: #f1f1f1;
# }
# #T_653f8_row6_col2 {
#   background-color: #e7e6f1;
#   color: #000000;
# }
# #T_653f8_row6_col4 {
#   background-color: #e0dfee;
#   color: #000000;
# }
# #T_653f8_row6_col7 {
#   background-color: #d9d9ea;
#   color: #000000;
# }
# #T_653f8_row6_col8 {
#   background-color: #cfd0e6;
#   color: #000000;
# }
# #T_653f8_row6_col9 {
#   background-color: #afaed4;
#   color: #000000;
# }
# #T_653f8_row7_col1 {
#   background-color: #a5a2cd;
#   color: #f1f1f1;
# }
# #T_653f8_row7_col2, #T_653f8_row7_col8 {
#   background-color: #eceaf3;
#   color: #000000;
# }
# #T_653f8_row7_col4 {
#   background-color: #d1d2e7;
#   color: #000000;
# }
# #T_653f8_row7_col5 {
#   background-color: #e1e0ee;
#   color: #000000;
# }
# #T_653f8_row7_col9 {
#   background-color: #694fa2;
#   color: #f1f1f1;
# }
# #T_653f8_row8_col0 {
#   background-color: #acaad1;
#   color: #000000;
# }
# #T_653f8_row8_col1 {
#   background-color: #faf8fb;
#   color: #000000;
# }
# #T_653f8_row8_col2 {
#   background-color: #a4a1cc;
#   color: #f1f1f1;
# }
# #T_653f8_row8_col3 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_653f8_row8_col4, #T_653f8_row8_col7 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_653f8_row8_col5 {
#   background-color: #dcdcec;
#   color: #000000;
# }
# #T_653f8_row8_col6 {
#   background-color: #b8b8d9;
#   color: #000000;
# }
# #T_653f8_row8_col9 {
#   background-color: #cacae3;
#   color: #000000;
# }
# #T_653f8_row9_col1 {
#   background-color: #8380bb;
#   color: #f1f1f1;
# }
# #T_653f8_row9_col3 {
#   background-color: #6e58a7;
#   color: #f1f1f1;
# }
# #T_653f8_row9_col4 {
#   background-color: #aaa8d0;
#   color: #000000;
# }
# #T_653f8_row9_col5 {
#   background-color: #ddddec;
#   color: #000000;
# }
# </style>
# <table id="T_653f8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_653f8_level0_col0" class="col_heading level0 col0" >RI</th>
#       <th id="T_653f8_level0_col1" class="col_heading level0 col1" >Na</th>
#       <th id="T_653f8_level0_col2" class="col_heading level0 col2" >Mg</th>
#       <th id="T_653f8_level0_col3" class="col_heading level0 col3" >Al</th>
#       <th id="T_653f8_level0_col4" class="col_heading level0 col4" >Si</th>
#       <th id="T_653f8_level0_col5" class="col_heading level0 col5" >K</th>
#       <th id="T_653f8_level0_col6" class="col_heading level0 col6" >Ca</th>
#       <th id="T_653f8_level0_col7" class="col_heading level0 col7" >Ba</th>
#       <th id="T_653f8_level0_col8" class="col_heading level0 col8" >Fe</th>
#       <th id="T_653f8_level0_col9" class="col_heading level0 col9" >Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_653f8_level0_row0" class="row_heading level0 row0" >RI</th>
#       <td id="T_653f8_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_653f8_row0_col1" class="data row0 col1" >-0.191885</td>
#       <td id="T_653f8_row0_col2" class="data row0 col2" >-0.122274</td>
#       <td id="T_653f8_row0_col3" class="data row0 col3" >-0.407326</td>
#       <td id="T_653f8_row0_col4" class="data row0 col4" >-0.542052</td>
#       <td id="T_653f8_row0_col5" class="data row0 col5" >-0.289833</td>
#       <td id="T_653f8_row0_col6" class="data row0 col6" >0.810403</td>
#       <td id="T_653f8_row0_col7" class="data row0 col7" >-0.000386</td>
#       <td id="T_653f8_row0_col8" class="data row0 col8" >0.143010</td>
#       <td id="T_653f8_row0_col9" class="data row0 col9" >-0.164237</td>
#     </tr>
#     <tr>
#       <th id="T_653f8_level0_row1" class="row_heading level0 row1" >Na</th>
#       <td id="T_653f8_row1_col0" class="data row1 col0" >-0.191885</td>
#       <td id="T_653f8_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_653f8_row1_col2" class="data row1 col2" >-0.273732</td>
#       <td id="T_653f8_row1_col3" class="data row1 col3" >0.156794</td>
#       <td id="T_653f8_row1_col4" class="data row1 col4" >-0.069809</td>
#       <td id="T_653f8_row1_col5" class="data row1 col5" >-0.266087</td>
#       <td id="T_653f8_row1_col6" class="data row1 col6" >-0.275442</td>
#       <td id="T_653f8_row1_col7" class="data row1 col7" >0.326603</td>
#       <td id="T_653f8_row1_col8" class="data row1 col8" >-0.241346</td>
#       <td id="T_653f8_row1_col9" class="data row1 col9" >0.502898</td>
#     </tr>
#     <tr>
#       <th id="T_653f8_level0_row2" class="row_heading level0 row2" >Mg</th>
#       <td id="T_653f8_row2_col0" class="data row2 col0" >-0.122274</td>
#       <td id="T_653f8_row2_col1" class="data row2 col1" >-0.273732</td>
#       <td id="T_653f8_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_653f8_row2_col3" class="data row2 col3" >-0.481799</

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.iloc[:,0:10]
y=df['Type']

# %%
xtr,xts,ytr,yts=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
xtr
# Out:
#           RI     Na    Mg    Al     Si     K    Ca   Ba    Fe  Type
# 16   1.51784  12.68  3.67  1.16  73.11  0.61  8.70  0.0  0.00     1
# 135  1.51789  13.19  3.90  1.30  72.33  0.55  8.44  0.0  0.28     2
# 122  1.51687  13.23  3.54  1.48  72.84  0.56  8.10  0.0  0.00     2
# 22   1.51736  12.78  3.62  1.29  72.79  0.59  8.70  0.0  0.00     1
# 80   1.51592  12.86  3.52  2.12  72.66  0.69  7.97  0.0  0.00     2
# ..       ...    ...   ...   ...    ...   ...   ...  ...   ...   ...
# 67   1.52152  13.05  3.65  0.87  72.32  0.19  9.85  0.0  0.17     1
# 192  1.51623  14.20  0.00  2.79  73.46  0.04  9.04  0.4  0.09     7
# 117  1.51708  13.72  3.68  1.81  72.06  0.64  7.88  0.0  0.00     2
# 47   1.52667  13.99  3.70  0.71  71.57  0.02  9.82  0.0  0.10     1
# 172  1.51321  13.00  0.00  3.02  70.70  6.21  6.93  0.0  0.00     5
#
# [171 rows x 10 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
mod=RandomForestClassifier()

# %%
mod.fit(xtr,ytr)
# Out:
# RandomForestClassifier()

# %%
pred=mod.predict(xts)
print(pred)
# Out:
# [7 1 2 6 5 2 2 2 1 2 1 2 3 2 2 7 2 1 3 3 5 2 7 7 2 1 7 1 2 2 1 1 2 2 2 3 1
#  3 2 7 2 6 2]

# %%
# Accuracy Checking.
from sklearn.metrics import accuracy_score

# %%
acc=accuracy_score(yts,pred)
print("Accuracy is:",acc*100)
# Out:
# Accuracy is: 100.0

# %%
# Evalution Metrics
from sklearn.metrics import confusion_matrix

# %%
# Confuse Matrix
c=confusion_matrix(yts,pred)
print("Confusion Matrix is: \n",c)
# Out:
# Confusion Matrix is:
#  [[ 9  0  0  0  0  0]
#  [ 0 19  0  0  0  0]
#  [ 0  0  5  0  0  0]
#  [ 0  0  0  2  0  0]
#  [ 0  0  0  0  2  0]
#  [ 0  0  0  0  0  6]]
